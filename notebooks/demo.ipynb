# %%
import sys
sys.path.append("..")
from spark_session import get_spark

spark = get_spark()

# Delta Lake
df = spark.createDataFrame([(1, "Alice"), (2, "Bob")], ["id", "name"])
df.write.format("delta").mode("overwrite").save("warehouse/delta/people")

spark.read.format("delta").load("warehouse/delta/people").show()

# Iceberg
spark.sql("CREATE TABLE IF NOT EXISTS iceberg.db.people (id INT, name STRING) USING iceberg")
df.writeTo("iceberg.db.people").append()
spark.table("iceberg.db.people").show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[2], line 14
#      10
#      11 spark.read.format("delta").load("warehouse/delta/people").show()
#      12
#      13 # Iceberg
# ---> 14 spark.sql("CREATE TABLE IF NOT EXISTS iceberg.db.people (id INT, name STRING) USING iceberg")
#      15 df.writeTo("iceberg.db.people").append()
#      16 spark.table("iceberg.db.people").show()
#
# File ~/projects/projeto-ed-satc/.venv/lib/python3.12/site-packages/pyspark/sql/session.py:1816, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1811     else:
#    1812         raise PySparkTypeError(
#    1813             errorClass="INVALID_TYPE",
#    1814             messageParameters={"arg_name": "args", "arg_type": type(args).__name__},
#    1815         )
# ...
